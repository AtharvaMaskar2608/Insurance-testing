# %% [markdown]
# # Insurance Calculation

# %% [markdown]
# ### 1. Reading commision sheet

# %%
import pandas as pd

# df = pd.read_excel("/home/choice/Desktop/Insuarance/Motor July grid (1).xlsx", sheet_name="Chola CV_Jul 24")

# Chola TW_Jul-24
df = pd.read_excel("/home/choice/Desktop/Insuarance/Motor July grid (1).xlsx", sheet_name="ICICI 06_2024- 4W & 2W Grid")

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                               Unnamed: 5  \
# 0                                    NaN
# 1  Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2       25% Maruti and Hyundai, Rest 15%
# 3                                   0.25
# 4                                   0.25
#
#                               Unnamed: 6 Unnamed: 7  \
# 0                                    NaN        NaN
# 1  Pvt Car Diesel & EV - 1+1 (NCB Cases)   SAOD-NCB
# 2                                   0.15      0.225
# 3                                   0.25       0.25
# 4                                  0.225       0.25
#
#                    Unnamed: 8            Unnamed: 9  \
# 0                         NaN                   NaN
# 1  Pvt Car-\n0 NCB ( NON NCB)  Pvt Car (Used Car**)
# 2                        0.15                  0.15
# 3                        0.15                  0.25
# 4                        0.15                  0.25
#
#                          Unnamed: 10           Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)                   NaN
# 1               Pvt car AOTP- Petrol  Pvt car AOTP- Diesel
# 2                               0.25                  0.05
# 3                               0.25                  0.15
# 4                               0.25                   0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13        Unnamed: 14  \
# 0                                         NaN                NaN
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)  TW Scooters- SAOD
# 2                                         0.1               0.35
# 3                                         0.4               0.35
# 4                                         0.4               0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                                   NaN                                NaN
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %% [markdown]
# ### 2. Handling Sheet

# %%
# Defining from which row, the table/header is starting 
# TODO: Make it dynamic

df_range = 0

# %%
df = df.iloc[df_range:]

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                               Unnamed: 5  \
# 0                                    NaN
# 1  Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2       25% Maruti and Hyundai, Rest 15%
# 3                                   0.25
# 4                                   0.25
#
#                               Unnamed: 6 Unnamed: 7  \
# 0                                    NaN        NaN
# 1  Pvt Car Diesel & EV - 1+1 (NCB Cases)   SAOD-NCB
# 2                                   0.15      0.225
# 3                                   0.25       0.25
# 4                                  0.225       0.25
#
#                    Unnamed: 8            Unnamed: 9  \
# 0                         NaN                   NaN
# 1  Pvt Car-\n0 NCB ( NON NCB)  Pvt Car (Used Car**)
# 2                        0.15                  0.15
# 3                        0.15                  0.25
# 4                        0.15                  0.25
#
#                          Unnamed: 10           Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)                   NaN
# 1               Pvt car AOTP- Petrol  Pvt car AOTP- Diesel
# 2                               0.25                  0.05
# 3                               0.25                  0.15
# 4                               0.25                   0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13        Unnamed: 14  \
# 0                                         NaN                NaN
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)  TW Scooters- SAOD
# 2                                         0.1               0.35
# 3                                         0.4               0.35
# 4                                         0.4               0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                                   NaN                                NaN
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Step 2: Drop rows with all NaN values
df = df.dropna(how='all').reset_index(drop=True)

# Drop columns where all values are NaN
df = df.dropna(axis=1, how='all')

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                               Unnamed: 5  \
# 0                                    NaN
# 1  Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2       25% Maruti and Hyundai, Rest 15%
# 3                                   0.25
# 4                                   0.25
#
#                               Unnamed: 6 Unnamed: 7  \
# 0                                    NaN        NaN
# 1  Pvt Car Diesel & EV - 1+1 (NCB Cases)   SAOD-NCB
# 2                                   0.15      0.225
# 3                                   0.25       0.25
# 4                                  0.225       0.25
#
#                    Unnamed: 8            Unnamed: 9  \
# 0                         NaN                   NaN
# 1  Pvt Car-\n0 NCB ( NON NCB)  Pvt Car (Used Car**)
# 2                        0.15                  0.15
# 3                        0.15                  0.25
# 4                        0.15                  0.25
#
#                          Unnamed: 10           Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)                   NaN
# 1               Pvt car AOTP- Petrol  Pvt car AOTP- Diesel
# 2                               0.25                  0.05
# 3                               0.25                  0.15
# 4                               0.25                   0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13        Unnamed: 14  \
# 0                                         NaN                NaN
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)  TW Scooters- SAOD
# 2                                         0.1               0.35
# 3                                         0.4               0.35
# 4                                         0.4               0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                                   NaN                                NaN
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Flash fill for all columns

## As per the above we see that there is null value in the column and that si due to the merge value in the original data to cover this filling the null value with previouse one
df = df.fillna(method='ffill', axis=1)
# Out:
# /tmp/ipykernel_13520/1606804452.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill', axis=1)

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                                           Unnamed: 5  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2                   25% Maruti and Hyundai, Rest 15%
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 6  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Diesel & EV - 1+1 (NCB Cases)
# 2                                               0.15
# 3                                               0.25
# 4                                              0.225
#
#                                           Unnamed: 7  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                           SAOD-NCB
# 2                                              0.225
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 8  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                         Pvt Car-\n0 NCB ( NON NCB)
# 2                                               0.15
# 3                                               0.15
# 4                                               0.15
#
#                                           Unnamed: 9  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                               Pvt Car (Used Car**)
# 2                                               0.15
# 3                                               0.25
# 4                                               0.25
#
#                          Unnamed: 10                        Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)  Private car AOTP  (Points on Net)
# 1               Pvt car AOTP- Petrol               Pvt car AOTP- Diesel
# 2                               0.25                               0.05
# 3                               0.25                               0.15
# 4                               0.25                                0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13                Unnamed: 14  \
# 0                   Scooters  (Points on Net)  Scooters  (Points on Net)
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)          TW Scooters- SAOD
# 2                                         0.1                       0.35
# 3                                         0.4                       0.35
# 4                                         0.4                       0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                              Bikes (Points on net)
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                 Bikes (Points on net)              Bikes (Points on net)
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Defining which row is the heading

heading_row = 0

# %%
# df.columns = df.iloc[heading_row]

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                                           Unnamed: 5  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2                   25% Maruti and Hyundai, Rest 15%
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 6  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Diesel & EV - 1+1 (NCB Cases)
# 2                                               0.15
# 3                                               0.25
# 4                                              0.225
#
#                                           Unnamed: 7  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                           SAOD-NCB
# 2                                              0.225
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 8  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                         Pvt Car-\n0 NCB ( NON NCB)
# 2                                               0.15
# 3                                               0.15
# 4                                               0.15
#
#                                           Unnamed: 9  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                               Pvt Car (Used Car**)
# 2                                               0.15
# 3                                               0.25
# 4                                               0.25
#
#                          Unnamed: 10                        Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)  Private car AOTP  (Points on Net)
# 1               Pvt car AOTP- Petrol               Pvt car AOTP- Diesel
# 2                               0.25                               0.05
# 3                               0.25                               0.15
# 4                               0.25                                0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13                Unnamed: 14  \
# 0                   Scooters  (Points on Net)  Scooters  (Points on Net)
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)          TW Scooters- SAOD
# 2                                         0.1                       0.35
# 3                                         0.4                       0.35
# 4                                         0.4                       0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                              Bikes (Points on net)
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                 Bikes (Points on net)              Bikes (Points on net)
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Dropping index of the heading

# df = df.drop(index=heading_row)

# %%
df.head(5)
# Out:
#   RTO CATEGORY RTO Zone       RTO State            RTO Location  \
# 0          NaN      NaN             NaN                     NaN
# 1          NaN      NaN             NaN                     NaN
# 2          Geo    South  ANDHRA PRADESH  Rest of Andhra Pradesh
# 3     Vertical    South  ANDHRA PRADESH               Vijaywada
# 4     Vertical    South  ANDHRA PRADESH          Visakhapatnam
#
#                                           Unnamed: 4  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                   Pvt Car New 1+3
# 2                                               0.25
# 3                                               0.25
# 4                                               0.15
#
#                                           Unnamed: 5  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Petrol & CNG- 1+1 (NCB Cases)
# 2                   25% Maruti and Hyundai, Rest 15%
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 6  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1              Pvt Car Diesel & EV - 1+1 (NCB Cases)
# 2                                               0.15
# 3                                               0.25
# 4                                              0.225
#
#                                           Unnamed: 7  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                                           SAOD-NCB
# 2                                              0.225
# 3                                               0.25
# 4                                               0.25
#
#                                           Unnamed: 8  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                         Pvt Car-\n0 NCB ( NON NCB)
# 2                                               0.15
# 3                                               0.15
# 4                                               0.15
#
#                                           Unnamed: 9  \
# 0  Private car- New, SAOD,Comp and Used Car      ...
# 1                               Pvt Car (Used Car**)
# 2                                               0.15
# 3                                               0.25
# 4                                               0.25
#
#                          Unnamed: 10                        Unnamed: 11  \
# 0  Private car AOTP  (Points on Net)  Private car AOTP  (Points on Net)
# 1               Pvt car AOTP- Petrol               Pvt car AOTP- Diesel
# 2                               0.25                               0.05
# 3                               0.25                               0.15
# 4                               0.25                                0.2
#
#                              Two Wheeler  \
# 0              Scooters  (Points on Net)
# 1  TW Scooters- Comp\n (1+1) (2+2) (3+3)
# 2                                    0.4
# 3                                   0.45
# 4                                   0.45
#
#                                   Unnamed: 13                Unnamed: 14  \
# 0                   Scooters  (Points on Net)  Scooters  (Points on Net)
# 1  TW Scooters - (TP only)\n(0+1) (0+2) (0+3)          TW Scooters- SAOD
# 2                                         0.1                       0.35
# 3                                         0.4                       0.35
# 4                                         0.4                       0.35
#
#                                          Unnamed: 15  \
# 0                              Bikes (Points on net)
# 1  TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Baj...
# 2                                            20% HMC
# 3                                  25% HMC, 40% HMSI
# 4                                                0.4
#
#                                          Unnamed: 16  \
# 0                              Bikes (Points on net)
# 1  TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0...
# 2                                               0.15
# 3                                                  0
# 4                                       30% HMC only
#
#                             Unnamed: 17                        Unnamed: 18  \
# 0                 Bikes (Points on net)              Bikes (Points on net)
# 1  TW Bikes -SAOD \n(All Manufacturers)  Royal Enfield- (SAOD/Comp/ AOTP)
# 2                                   0.3                                  0
# 3                                   0.3                                0.4
# 4                                   0.3                                0.4
#
#                            Unnamed: 19
# 0  EV-TW (Registered & Non Registered)
# 1             TW - EV (SAOD/Comp/AOTP)
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Step 1: Replace null or unnamed headers with inferred names (if needed)
unnamed_columns = df.columns.str.contains('^Unnamed')
new_columns = []
last_valid_header = None

for i, col in enumerate(df.columns):
    if unnamed_columns[i]:
        if last_valid_header is not None:
            new_columns.append(last_valid_header)
        else:
            new_columns.append('Unnamed')
    else:
        new_columns.append(col)
        last_valid_header = col

df.columns = new_columns

# Function to find the first numerical value row index
def find_first_numerical_row(df):
    for idx, row in df.iterrows():
        if row.apply(lambda x: isinstance(x, (int, float)) or (isinstance(x, str) and x.isdigit())).any():
            return idx
    return None

# Step 2: Find the first numerical row
first_num_row_idx = find_first_numerical_row(df)

# Step 3: Extract original headers and rows above the first numerical row
original_headers = df.columns.tolist()
above_rows = df.iloc[:first_num_row_idx]

# first_row = above_rows.iloc[0].tolist()

# Collect all values from above rows into a single list
above_rows_values = []
for idx in range(first_num_row_idx):
    above_rows_values.extend(above_rows.iloc[idx].tolist())

# # Step 3: Combine the original headers with the first row of data
# combined_headers = [f"{str(header)}_{str(first_row_value)}" for header, first_row_value in zip(original_headers,  first_row)]


combined_headers =  [f"{str(header)}_{str(value)}" for header, value in zip(original_headers, above_rows_values)]
# # Step 4: Create a new DataFrame with combined headers and the rest of the data
# df = pd.DataFrame(df.iloc[1:].values, columns=combined_headers)

new_df = pd.DataFrame(df.iloc[first_num_row_idx:].values, columns=combined_headers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 47
#      43 combined_headers =  [f"{str(header)}_{str(value)}" for header, value in zip(original_headers, above_rows_values)]
#      44 # # Step 4: Create a new DataFrame with combined headers and the rest of the data
#      45 # df = pd.DataFrame(df.iloc[1:].values, columns=combined_headers)
# ---> 47 new_df = pd.DataFrame(df.iloc[first_num_row_idx:].values, columns=combined_headers)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (57, 20), indices imply (57, 0)

# %%
new_df.head(5)
# Out:
#   RTO CATEGORY_nan RTO Zone_nan      RTO State_nan        RTO Location_nan  \
# 0              Geo        South     ANDHRA PRADESH  Rest of Andhra Pradesh
# 1         Vertical        South     ANDHRA PRADESH               Vijaywada
# 2         Vertical        South     ANDHRA PRADESH          Visakhapatnam
# 3              Geo         East  Arunachal Pradesh       Arunachal Pradesh
# 4              Geo         East              Assam                   Assam
#
#   RTO Location_Pvt Car New 1+3   \
# 0                          0.25
# 1                          0.25
# 2                          0.15
# 3                           0.1
# 4                           0.1
#
#   RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)  \
# 0                   25% Maruti and Hyundai, Rest 15%
# 1                                               0.25
# 2                                               0.25
# 3                                               0.25
# 4                                                0.1
#
#   RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases) RTO Location_SAOD-NCB  \
# 0                                               0.15                 0.225
# 1                                               0.25                  0.25
# 2                                              0.225                  0.25
# 3                                               0.25                  0.25
# 4                                                0.1                 0.225
#
#   RTO Location_Pvt Car-\n0 NCB ( NON NCB) RTO Location_Pvt Car (Used Car**)  \
# 0                                    0.15                              0.15
# 1                                    0.15                              0.25
# 2                                    0.15                              0.25
# 3                                    0.15                              0.25
# 4                                    0.15                              0.15
#
#   RTO Location_Pvt car AOTP- Petrol RTO Location_Pvt car AOTP- Diesel  \
# 0                              0.25                              0.05
# 1                              0.25                              0.15
# 2                              0.25                               0.2
# 3                              0.15                              0.05
# 4                           Decline                           Decline
#
#   Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)  \
# 0                                               0.4
# 1                                              0.45
# 2                                              0.45
# 3                                               0.4
# 4                                               0.3
#
#   Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.4
# 3                                                0.5
# 4                                            Decline
#
#   Two Wheeler_TW Scooters- SAOD  \
# 0                          0.35
# 1                          0.35
# 2                          0.35
# 3                           0.4
# 4                           0.3
#
#   Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)  \
# 0                                            20% HMC
# 1                                  25% HMC, 40% HMSI
# 2                                                0.4
# 3                                   25% HMC and HMSI
# 4                                                  0
#
#   Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3)   \
# 0                                               0.15
# 1                                                  0
# 2                                       30% HMC only
# 3                                               0.15
# 4                                                  0
#
#   Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)  \
# 0                                              0.3
# 1                                              0.3
# 2                                              0.3
# 3                                              0.3
# 4                                              0.3
#
#   Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP)   \
# 0                                             0
# 1                                           0.4
# 2                                           0.4
# 3                                           0.3
# 4                                             0
#
#   Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 0                                  0.3
# 1                                  0.3
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
## As per the above we see that there is null value in the column and that si due to the merge value in the original data to cover this filling the null value with previouse one

# Flash Fill for columns
new_df = new_df.fillna(method='ffill', axis=0)
# Out:
# /tmp/ipykernel_13520/1887811094.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = new_df.fillna(method='ffill', axis=0)

# %%
new_df.head(5)
# Out:
#   RTO CATEGORY_nan RTO Zone_nan      RTO State_nan        RTO Location_nan  \
# 0              Geo        South     ANDHRA PRADESH  Rest of Andhra Pradesh
# 1         Vertical        South     ANDHRA PRADESH               Vijaywada
# 2         Vertical        South     ANDHRA PRADESH          Visakhapatnam
# 3              Geo         East  Arunachal Pradesh       Arunachal Pradesh
# 4              Geo         East              Assam                   Assam
#
#   RTO Location_Pvt Car New 1+3   \
# 0                          0.25
# 1                          0.25
# 2                          0.15
# 3                           0.1
# 4                           0.1
#
#   RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)  \
# 0                   25% Maruti and Hyundai, Rest 15%
# 1                                               0.25
# 2                                               0.25
# 3                                               0.25
# 4                                                0.1
#
#   RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases) RTO Location_SAOD-NCB  \
# 0                                               0.15                 0.225
# 1                                               0.25                  0.25
# 2                                              0.225                  0.25
# 3                                               0.25                  0.25
# 4                                                0.1                 0.225
#
#   RTO Location_Pvt Car-\n0 NCB ( NON NCB) RTO Location_Pvt Car (Used Car**)  \
# 0                                    0.15                              0.15
# 1                                    0.15                              0.25
# 2                                    0.15                              0.25
# 3                                    0.15                              0.25
# 4                                    0.15                              0.15
#
#   RTO Location_Pvt car AOTP- Petrol RTO Location_Pvt car AOTP- Diesel  \
# 0                              0.25                              0.05
# 1                              0.25                              0.15
# 2                              0.25                               0.2
# 3                              0.15                              0.05
# 4                           Decline                           Decline
#
#   Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)  \
# 0                                               0.4
# 1                                              0.45
# 2                                              0.45
# 3                                               0.4
# 4                                               0.3
#
#   Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.4
# 3                                                0.5
# 4                                            Decline
#
#   Two Wheeler_TW Scooters- SAOD  \
# 0                          0.35
# 1                          0.35
# 2                          0.35
# 3                           0.4
# 4                           0.3
#
#   Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)  \
# 0                                            20% HMC
# 1                                  25% HMC, 40% HMSI
# 2                                                0.4
# 3                                   25% HMC and HMSI
# 4                                                  0
#
#   Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3)   \
# 0                                               0.15
# 1                                                  0
# 2                                       30% HMC only
# 3                                               0.15
# 4                                                  0
#
#   Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)  \
# 0                                              0.3
# 1                                              0.3
# 2                                              0.3
# 3                                              0.3
# 4                                              0.3
#
#   Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP)   \
# 0                                             0
# 1                                           0.4
# 2                                           0.4
# 3                                           0.3
# 4                                             0
#
#   Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 0                                  0.3
# 1                                  0.3
# 2                                  0.3
# 3                                  0.3
# 4                                  0.3

# %%
# Index from which commision starts
index = 4

value = new_df.columns[:index]

# %%
value
# Out:
# Index(['RTO CATEGORY_nan', 'RTO Zone_nan', 'RTO State_nan',
#        'RTO Location_nan'],
#       dtype='object')

# %%
new_df.columns.dtype
# Out:
# dtype('O')

# %%
# Melt the DataFrame
id_vars = value
value_vars = [col for col in new_df.columns if col not in id_vars]
melted_df = pd.melt(new_df, id_vars=id_vars, value_vars=value_vars, 
                    var_name='variable', value_name='value')

# %%
melted_df
# Out:
#     RTO CATEGORY_nan              RTO Zone_nan  \
# 0                Geo                     South
# 1           Vertical                     South
# 2           Vertical                     South
# 3                Geo                      East
# 4                Geo                      East
# ..               ...                       ...
# 875                1  Private car- Comp & SAOD
# 876                2    Private Car - Used Car
# 877                3                        2W
# 878                4                  2W (1+5)
# 879                5                      All
#
#                                          RTO State_nan  \
# 0                                       ANDHRA PRADESH
# 1                                       ANDHRA PRADESH
# 2                                       ANDHRA PRADESH
# 3                                    Arunachal Pradesh
# 4                                                Assam
# ..                                                 ...
# 875  Private car Comp & SAOD: No points on Negative...
# 876  Subject to transaction as USED car only in NYS...
# 877     NO Points on Bajaj, Suzuki, TVS & Yamaha Bikes
# 878            TW Grid New 1+5, 2.5% lower without CPA
# 879  Any segment not mentioned in the grid/declined...
#
#                                       RTO Location_nan  \
# 0                               Rest of Andhra Pradesh
# 1                                            Vijaywada
# 2                                       Visakhapatnam
# 3                                    Arunachal Pradesh
# 4                                                Assam
# ..                                                 ...
# 875  Private car Comp & SAOD: No points on Negative...
# 876  Subject to transaction as USED car only in NYS...
# 877     NO Points on Bajaj, Suzuki, TVS & Yamaha Bikes
# 878            TW Grid New 1+5, 2.5% lower without CPA
# 879  Any segment not mentioned in the grid/declined...
#
#                                  variable  \
# 0           RTO Location_Pvt Car New 1+3
# 1           RTO Location_Pvt Car New 1+3
# 2           RTO Location_Pvt Car New 1+3
# 3           RTO Location_Pvt Car New 1+3
# 4           RTO Location_Pvt Car New 1+3
# ..                                    ...
# 875  Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 876  Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 877  Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 878  Two Wheeler_TW - EV (SAOD/Comp/AOTP)
# 879  Two Wheeler_TW - EV (SAOD/Comp/AOTP)
#
#                                                  value
# 0                                                 0.25
# 1                                                 0.25
# 2                                                 0.15
# 3                                                  0.1
# 4                                                  0.1
# ..                                                 ...
# 875  Private car Comp & SAOD: No points on Negative...
# 876  Subject to transaction as USED car only in NYS...
# 877     NO Points on Bajaj, Suzuki, TVS & Yamaha Bikes
# 878            TW Grid New 1+5, 2.5% lower without CPA
# 879  Any segment not mentioned in the grid/declined...
#
# [880 rows x 6 columns]

# %%
import pandas as pd

# Read the Excel file into a DataFrame
# df = pd.read_excel('your_file.xlsx')

# Sample DataFrame


# Define the hierarchical levels
levels = melted_df.columns

def build_tree(df, levels):
    if len(levels) == 1:
        return df[levels[0]].tolist()
    
    unique_values = df[levels[0]].unique()
    tree = {}
    for value in unique_values:
        subtree_df = df[df[levels[0]] == value]
        tree[value] = build_tree(subtree_df, levels[1:])
    
    return tree

# Build the hierarchical tree
tree = build_tree(melted_df, levels)

# Print the tree
import pprint
pprint.pprint(tree)
# Out:
# {1: {'Private car- Comp & SAOD': {'Private car Comp & SAOD: No points on Negative Models (NCB & Non NCB) like - Bolero,Tavera,Qualis,Indica,Indigo, Omni, Eeco, , TATA Sumo, Hyundai Getz, GM, Chevrolet and absolete Models) ': {'Private car Comp & SAOD: No points on Negative Models (NCB & Non NCB) like - Bolero,Tavera,Qualis,Indica,Indigo, Omni, Eeco, , TATA Sumo, Hyundai Getz, GM, Chevrolet and absolete Models) ': {'RTO Location_Pvt Car (Used Car**)': ['Private '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'car '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Comp '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'SAOD: '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'No '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'points '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'on '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Negative '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Models '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '(NCB '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Non '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'NCB) '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'like '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '- '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Bolero,Tavera,Qualis,Indica,Indigo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Omni, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Eeco, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ', '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'TATA '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Sumo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Hyundai '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Getz, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'GM, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Chevrolet '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'and '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'absolete '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Models) '],
#                                                                                                                                                                                                                                                                                                                                                                                                                                   'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': ['Private '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'car '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Comp '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'SAOD: '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'No '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'points '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'on '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Negative '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Models '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '(NCB '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Non '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'NCB) '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'like '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '- '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Bolero,Tavera,Qualis,Indica,Indigo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Omni, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Eeco, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ', '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'TATA '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Sumo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Hyundai '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Getz, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'GM, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Chevrolet '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'and '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'absolete '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Models) '],
#                                                                                                                                                                                                                                                                                                                                                                                                                                   'RTO Location_Pvt Car New 1+3 ': ['Private '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'car '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Comp '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'SAOD: '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'No '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'points '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'on '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Negative '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Models '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '(NCB '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Non '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'NCB) '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'like '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '- '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Bolero,Tavera,Qualis,Indica,Indigo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Omni, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Eeco, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ', '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'TATA '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Sumo, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Hyundai '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Getz, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'GM, '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Chevrolet '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'and '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'absolete '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Models) '],
#                                                                                                                                                                                                                                                                                                                                                                                                                                   'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': ['Private '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'car '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Comp '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'SAOD: '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'No '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'points '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'on '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Negative '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Models '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '(NCB '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '& '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Non '
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'NCB) '
# ...
#                                                  'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                                  'RTO Location_Pvt car AOTP- Diesel': [0.3],
#                                                  'RTO Location_Pvt car AOTP- Petrol': [0.35],
#                                                  'RTO Location_SAOD-NCB': [0.25],
#                                                  'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                                  'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                                  'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                                  'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0.4],
#                                                  'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': [0.35],
#                                                  'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                                  'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                                  'Two Wheeler_TW Scooters- SAOD': [0.2]},
#                                    'Baroda': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                               'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.25],
#                                               'RTO Location_Pvt Car New 1+3 ': [0.3],
#                                               'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.3],
#                                               'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                               'RTO Location_Pvt car AOTP- Diesel': [0.2],
#                                               'RTO Location_Pvt car AOTP- Petrol': [0.3],
#                                               'RTO Location_SAOD-NCB': [0.225],
#                                               'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                               'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                               'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                               'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': ['40% '
#                                                                                                                                         'on '
#                                                                                                                                         'HMSI, '
#                                                                                                                                         '30% '
#                                                                                                                                         'HMC '
#                                                                                                                                         'only'],
#                                               'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': ['40% '
#                                                                                                                       'on '
#                                                                                                                       'HMSI, '
#                                                                                                                       '10% '
#                                                                                                                       'HMC '
#                                                                                                                       'only'],
#                                               'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                               'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                               'Two Wheeler_TW Scooters- SAOD': [0.25]},
#                                    'Rajkot': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                               'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.25],
#                                               'RTO Location_Pvt Car New 1+3 ': [0.3],
#                                               'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.25],
#                                               'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                               'RTO Location_Pvt car AOTP- Diesel': [0.3],
#                                               'RTO Location_Pvt car AOTP- Petrol': [0.35],
#                                               'RTO Location_SAOD-NCB': [0.25],
#                                               'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                               'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                               'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                               'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0.4],
#                                               'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': [0.2],
#                                               'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                               'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                               'Two Wheeler_TW Scooters- SAOD': [0]},
#                                    'Surat': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                              'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.225],
#                                              'RTO Location_Pvt Car New 1+3 ': [0.3],
#                                              'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.3],
#                                              'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                              'RTO Location_Pvt car AOTP- Diesel': [0.3],
#                                              'RTO Location_Pvt car AOTP- Petrol': [0.3],
#                                              'RTO Location_SAOD-NCB': [0.225],
#                                              'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                              'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                              'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                              'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0.4],
#                                              'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': ['35% '
#                                                                                                                      'HMC '
#                                                                                                                      'and '
#                                                                                                                      '20% '
#                                                                                                                      'HMSI'],
#                                              'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                              'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                              'Two Wheeler_TW Scooters- SAOD': [0.15]}},
#                        'MADHYA PRADESH': {'Indore': {'RTO Location_Pvt Car (Used Car**)': [0.195],
#                                                      'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.15],
#                                                      'RTO Location_Pvt Car New 1+3 ': [0.25],
#                                                      'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.15],
#                                                      'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                                      'RTO Location_Pvt car AOTP- Diesel': [0.3],
#                                                      'RTO Location_Pvt car AOTP- Petrol': [0.3],
#                                                      'RTO Location_SAOD-NCB': [0.25],
#                                                      'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.25],
#                                                      'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                                      'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                                      'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0],
#                                                      'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': [0],
#                                                      'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.4],
#                                                      'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.45],
#                                                      'Two Wheeler_TW Scooters- SAOD': [0.25]}},
#                        'Maharashtra': {'Mumbai': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                                   'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.3],
#                                                   'RTO Location_Pvt Car New 1+3 ': [0.3],
#                                                   'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.3],
#                                                   'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                                   'RTO Location_Pvt car AOTP- Diesel': [0.15],
#                                                   'RTO Location_Pvt car AOTP- Petrol': [0.35],
#                                                   'RTO Location_SAOD-NCB': [0.25],
#                                                   'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                                   'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                                   'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                                   'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0.4],
#                                                   'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': ['30% '
#                                                                                                                           'HMSI '
#                                                                                                                           '(Honda '
#                                                                                                                           'MotorCycle)'],
#                                                   'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                                   'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                                   'Two Wheeler_TW Scooters- SAOD': [0.25]},
#                                        'Nagpur': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                                   'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.25],
#                                                   'RTO Location_Pvt Car New 1+3 ': [0.25],
#                                                   'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.3],
#                                                   'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                                   'RTO Location_Pvt car AOTP- Diesel': [0.05],
#                                                   'RTO Location_Pvt car AOTP- Petrol': [0.35],
#                                                   'RTO Location_SAOD-NCB': [0.225],
#                                                   'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.4],
#                                                   'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                                   'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                                   'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': ['35% '
#                                                                                                                                             'HMC '
#                                                                                                                                             'and '
#                                                                                                                                             '25% '
#                                                                                                                                             'HMSI'],
#                                                   'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': ['40% '
#                                                                                                                           'HMC '
#                                                                                                                           'only'],
#                                                   'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                                   'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                                   'Two Wheeler_TW Scooters- SAOD': [0.25]},
#                                        'Pune': {'RTO Location_Pvt Car (Used Car**)': [0.25],
#                                                 'RTO Location_Pvt Car Diesel & EV - 1+1 (NCB Cases)': [0.225],
#                                                 'RTO Location_Pvt Car New 1+3 ': [0.3],
#                                                 'RTO Location_Pvt Car Petrol & CNG- 1+1 (NCB Cases)': [0.3],
#                                                 'RTO Location_Pvt Car-\n0 NCB ( NON NCB)': [0.15],
#                                                 'RTO Location_Pvt car AOTP- Diesel': [0.35],
#                                                 'RTO Location_Pvt car AOTP- Petrol': [0.35],
#                                                 'RTO Location_SAOD-NCB': [0.225],
#                                                 'Two Wheeler_Royal Enfield- (SAOD/Comp/ AOTP) ': [0.2],
#                                                 'Two Wheeler_TW - EV (SAOD/Comp/AOTP)': [0.3],
#                                                 'Two Wheeler_TW Bikes -SAOD \n(All Manufacturers)': [0.3],
#                                                 'Two Wheeler_TW Bikes Comp (1+1) (2+2) (3+3) (Excluding Bajaj, Yamaha, TVS and Suzuki)': [0.4],
#                                                 'Two Wheeler_TW Bikes- AOTP \n(All Manufacturers) \n(0+1, 0+2, 0+3) ': [0.3],
#                                                 'Two Wheeler_TW Scooters - (TP only)\n(0+1) (0+2) (0+3)': [0.55],
#                                                 'Two Wheeler_TW Scooters- Comp\n (1+1) (2+2) (3+3)': [0.55],
#                                                 'Two Wheeler_TW Scooters- SAOD': [0.25]}}}}}

# %%
import json

with open("ICICI.json", "w") as jsonFile:
    json.dump(tree, jsonFile, indent=4)
