# %% [markdown]
# # Insurance Calculation

# %% [markdown]
# ### 1. Reading commision sheet

# %%
import pandas as pd

# df = pd.read_excel("/home/choice/Desktop/Insuarance/Motor July grid (1).xlsx", sheet_name="Chola CV_Jul 24")

# Chola TW_Jul-24
df = pd.read_excel("/home/choice/Desktop/Insuarance/United_July24.xlsx")

# %%
df.head(8)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
# 5              NaN                                                NaN
# 6              NaN                                                NaN
# 7              NaN                                                NaN
#
#                            Renewal Comm on Net Premium of 1st year  \
# 0                              0.2                             NaN
# 1                              NaN                             NaN
# 2                             0.15                             NaN
# 3                              NaN                             NaN
# 4                        New - 10%                             NaN
# 5                      Package -5%                             NaN
# 6  SAOD renewal -7%, rollover - 5%                             NaN
# 7                          TP - 5%                             NaN
#
#    Unnamed: 4 Unnamed: 5
# 0         NaN       TATA
# 1         NaN     TOYOTA
# 2         NaN     MARUTI
# 3         NaN   MAHINDRA
# 4         NaN      HONDA
# 5         NaN    HYUNDAI
# 6         NaN        KIA
# 7         NaN        NaN

# %% [markdown]
# ### 2. Handling Sheet

# %%
# Defining from which row, the table/header is starting 
# TODO: Make it dynamic

df_range = 0

# %%
df = df.iloc[df_range:]

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year  Unnamed: 4 Unnamed: 5
# 0        0.2                             NaN         NaN       TATA
# 1        NaN                             NaN         NaN     TOYOTA
# 2       0.15                             NaN         NaN     MARUTI
# 3        NaN                             NaN         NaN   MAHINDRA
# 4  New - 10%                             NaN         NaN      HONDA

# %%
# Step 2: Drop rows with all NaN values
df = df.dropna(how='all').reset_index(drop=True)

# Drop columns where all values are NaN
df = df.dropna(axis=1, how='all')

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Unnamed: 5
# 0        0.2                             NaN       TATA
# 1        NaN                             NaN     TOYOTA
# 2       0.15                             NaN     MARUTI
# 3        NaN                             NaN   MAHINDRA
# 4  New - 10%                             NaN      HONDA

# %%
# Flash fill for all columns

## As per the above we see that there is null value in the column and that si due to the merge value in the original data to cover this filling the null value with previouse one
df = df.fillna(method='ffill', axis=1)
# Out:
# /tmp/ipykernel_14241/1606804452.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill', axis=1)

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Unnamed: 5
# 0        0.2                             0.2       TATA
# 1        NaN                             NaN     TOYOTA
# 2       0.15                            0.15     MARUTI
# 3        NaN                             NaN   MAHINDRA
# 4  New - 10%                       New - 10%      HONDA

# %%
# Defining which row is the heading

heading_row = 0

# %%
df.columns = df.iloc[heading_row]

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Unnamed: 5
# 0        0.2                             0.2       TATA
# 1        NaN                             NaN     TOYOTA
# 2       0.15                            0.15     MARUTI
# 3        NaN                             NaN   MAHINDRA
# 4  New - 10%                       New - 10%      HONDA

# %%
# Dropping index of the heading

df = df.drop(index=heading_row)

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Unnamed: 5
# 0        0.2                             0.2       TATA
# 1        NaN                             NaN     TOYOTA
# 2       0.15                            0.15     MARUTI
# 3        NaN                             NaN   MAHINDRA
# 4  New - 10%                       New - 10%      HONDA

# %%
# Step 1: Replace null or unnamed headers with inferred names (if needed)
unnamed_columns = df.columns.str.contains('^Unnamed')
new_columns = []
last_valid_header = None

for i, col in enumerate(df.columns):
    if unnamed_columns[i]:
        if last_valid_header is not None:
            new_columns.append(last_valid_header)
        else:
            new_columns.append('Unnamed')
    else:
        new_columns.append(col)
        last_valid_header = col

df.columns = new_columns

# Function to find the first numerical value row index
def find_first_numerical_row(df):
    for idx, row in df.iterrows():
        if row.apply(lambda x: isinstance(x, (int, float)) or (isinstance(x, str) and x.isdigit())).any():
            return idx
    return None

# Step 2: Find the first numerical row
first_num_row_idx = find_first_numerical_row(df)

# Step 3: Extract original headers and rows above the first numerical row
original_headers = df.columns.tolist()
above_rows = df.iloc[:first_num_row_idx]

# first_row = above_rows.iloc[0].tolist()

# Collect all values from above rows into a single list
above_rows_values = []
for idx in range(first_num_row_idx):
    above_rows_values.extend(above_rows.iloc[idx].tolist())

# # Step 3: Combine the original headers with the first row of data
# combined_headers = [f"{str(header)}_{str(first_row_value)}" for header, first_row_value in zip(original_headers,  first_row)]


combined_headers =  [f"{str(header)}_{str(value)}" for header, value in zip(original_headers, above_rows_values)]
# # Step 4: Create a new DataFrame with combined headers and the rest of the data
# df = pd.DataFrame(df.iloc[1:].values, columns=combined_headers)

new_df = pd.DataFrame(df.iloc[first_num_row_idx:].values, columns=combined_headers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 47
#      43 combined_headers =  [f"{str(header)}_{str(value)}" for header, value in zip(original_headers, above_rows_values)]
#      44 # # Step 4: Create a new DataFrame with combined headers and the rest of the data
#      45 # df = pd.DataFrame(df.iloc[1:].values, columns=combined_headers)
# ---> 47 new_df = pd.DataFrame(df.iloc[first_num_row_idx:].values, columns=combined_headers)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (35, 5), indices imply (35, 0)

# %%
df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1              NaN                                                NaN
# 2              NaN                                        above 350cc
# 3              NaN                                                NaN
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Comm on Net Premium of 1st year
# 0        0.2                             0.2                            TATA
# 1        NaN                             NaN                          TOYOTA
# 2       0.15                            0.15                          MARUTI
# 3        NaN                             NaN                        MAHINDRA
# 4  New - 10%                       New - 10%                           HONDA

# %%
## As per the above we see that there is null value in the column and that si due to the merge value in the original data to cover this filling the null value with previouse one

# Flash Fill for columns
new_df = df.fillna(method='ffill', axis=0)
# Out:
# /tmp/ipykernel_14241/2144302754.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method='ffill', axis=0)

# %%
new_df.head(5)
# Out:
#   Class of vehicle                                               Type  \
# 0      Two wheeler                           upto 350 cc AND ELECTRIC
# 1      Two wheeler                           upto 350 cc AND ELECTRIC
# 2      Two wheeler                                        above 350cc
# 3      Two wheeler                                        above 350cc
# 4          Pvt Car  Diesel upto 1500cc (all model will cover)and a...
#
#      Renewal Comm on Net Premium of 1st year Comm on Net Premium of 1st year
# 0        0.2                             0.2                            TATA
# 1        0.2                             0.2                          TOYOTA
# 2       0.15                            0.15                          MARUTI
# 3       0.15                            0.15                        MAHINDRA
# 4  New - 10%                       New - 10%                           HONDA

# %%
# Index from which commision starts
index = 2

value = new_df.columns[:index]

# %%
value
# Out:
# Index(['Class of vehicle', 'Type'], dtype='object')

# %%
new_df.columns.dtype
# Out:
# dtype('O')

# %%
# Melt the DataFrame
id_vars = value
value_vars = [col for col in new_df.columns if col not in id_vars]
melted_df = pd.melt(new_df, id_vars=id_vars, value_vars=value_vars, 
                    var_name='variable', value_name='value')

# %%
melted_df
# Out:
#                                       Class of vehicle  \
# 0                                          Two wheeler
# 1                                          Two wheeler
# 2                                          Two wheeler
# 3                                          Two wheeler
# 4                                              Pvt Car
# ..                                                 ...
# 100                                                GCV
# 101                                                GCV
# 102                                                GCV
# 103  Miscellaneous (Mobile cranes, Tractors, RMC, E...
# 104  Miscellaneous (Mobile cranes, Tractors, RMC, E...
#
#                                                   Type  \
# 0                             upto 350 cc AND ELECTRIC
# 1                             upto 350 cc AND ELECTRIC
# 2                                          above 350cc
# 3                                          above 350cc
# 4    Diesel upto 1500cc (all model will cover)and a...
# ..                                                 ...
# 100                                  20001 to 32000 kg
# 101                                  32001 to 40000 kg
# 102                                     above 40000 kg
# 103                                            Package
# 104                                                 TP
#
#                             variable  \
# 0                            Renewal
# 1                            Renewal
# 2                            Renewal
# 3                            Renewal
# 4                            Renewal
# ..                               ...
# 100  Comm on Net Premium of 1st year
# 101  Comm on Net Premium of 1st year
# 102  Comm on Net Premium of 1st year
# 103  Comm on Net Premium of 1st year
# 104  Comm on Net Premium of 1st year
#
#                                                  value
# 0                                                  0.2
# 1                                                  0.2
# 2                                                 0.15
# 3                                                 0.15
# 4                                            New - 10%
# ..                                                 ...
# 100                                               0.07
# 101                                               0.05
# 102                                               0.04
# 103                             15% in OD and 8% in TP
# 104  Mobile cranes, Tractors, RMC, Excavators, Bull...
#
# [105 rows x 4 columns]

# %%
import pandas as pd

# Read the Excel file into a DataFrame
# df = pd.read_excel('your_file.xlsx')

# Sample DataFrame


# Define the hierarchical levels
levels = melted_df.columns

def build_tree(df, levels):
    if len(levels) == 1:
        return df[levels[0]].tolist()
    
    unique_values = df[levels[0]].unique()
    tree = {}
    for value in unique_values:
        subtree_df = df[df[levels[0]] == value]
        tree[value] = build_tree(subtree_df, levels[1:])
    
    return tree

# Build the hierarchical tree
tree = build_tree(melted_df, levels)

# Print the tree
import pprint
pprint.pprint(tree)
# Out:
# {'GCV': {'10001 to 12000 kg': {'Comm on Net Premium of 1st year': ['Package OD '
#                                                                    '- 4% TP - '
#                                                                    '5%',
#                                                                    'TP 5%',
#                                                                    'Package OD '
#                                                                    '- 4% TP - '
#                                                                    '5%',
#                                                                    'TP 5%'],
#                                'Renewal': ['Package OD - 4% TP - 5%', 'TP 5%']},
#          '12001 to 20000 kg': {'Comm on Net Premium of 1st year': [0.05, 0.05],
#                                'Renewal': [0.05]},
#          '20001 to 32000 kg': {'Comm on Net Premium of 1st year': [0.07, 0.07],
#                                'Renewal': [0.07]},
#          '2001 to 10000 kg': {'Comm on Net Premium of 1st year': ['Package OD '
#                                                                   '- 15% TP - '
#                                                                   '20%',
#                                                                   'TP 20%',
#                                                                   'Package OD '
#                                                                   '- 15% TP - '
#                                                                   '20%',
#                                                                   'TP 20%'],
#                               'Renewal': ['Package OD - 15% TP - 20%',
#                                           'TP 20%']},
#          '32001 to 40000 kg': {'Comm on Net Premium of 1st year': [0.05, 0.05],
#                                'Renewal': [0.05]},
#          'Upto 2000 kg': {'Comm on Net Premium of 1st year': ['25% in Net '
#                                                               'Premium',
#                                                               '25% in Net '
#                                                               'Premium'],
#                           'Renewal': ['25% in Net Premium']},
#          'above 40000 kg': {'Comm on Net Premium of 1st year': [0.04, 0.04],
#                             'Renewal': [0.04]}},
#  'Miscellaneous (Mobile cranes, Tractors, RMC, Excavators, Bulldozers(Earth Moving Equipments), Ambulance )': {'Package': {'Comm on Net Premium of 1st year': ['15% '
#                                                                                                                                                                'in '
#                                                                                                                                                                'OD '
#                                                                                                                                                                'and '
#                                                                                                                                                                '8% '
#                                                                                                                                                                'in '
#                                                                                                                                                                'TP',
#                                                                                                                                                                '15% '
#                                                                                                                                                                'in '
#                                                                                                                                                                'OD '
#                                                                                                                                                                'and '
#                                                                                                                                                                '8% '
#                                                                                                                                                                'in '
#                                                                                                                                                                'TP'],
#                                                                                                                            'Renewal': ['15% '
#                                                                                                                                        'in '
#                                                                                                                                        'OD '
#                                                                                                                                        'and '
#                                                                                                                                        '8% '
#                                                                                                                                        'in '
#                                                                                                                                        'TP']},
#                                                                                                                'TP': {'Comm on Net Premium of 1st year': ['Mobile '
#                                                                                                                                                           'cranes, '
#                                                                                                                                                           'Tractors, '
#                                                                                                                                                           'RMC, '
#                                                                                                                                                           'Excavators, '
#                                                                                                                                                           'Bulldozers(Earth '
#                                                                                                                                                           'Moving '
#                                                                                                                                                           'Equipments), '
#                                                                                                                                                           'Ambulance ',
#                                                                                                                                                           'Mobile '
#                                                                                                                                                           'cranes, '
#                                                                                                                                                           'Tractors, '
#                                                                                                                                                           'RMC, '
#                                                                                                                                                           'Excavators, '
#                                                                                                                                                           'Bulldozers(Earth '
#                                                                                                                                                           'Moving '
#                                                                                                                                                           'Equipments), '
#                                                                                                                                                           'Ambulance '],
#                                                                                                                       'Renewal': [0.08]}},
#  'PCV': {'21 to 30 Passengers': {'Comm on Net Premium of 1st year': ['10% in '
#                                                                      'Net '
#                                                                      'Premium',
#                                                                      '10% in '
#                                                                      'Net '
#                                                                      'Premium'],
#                                  'Renewal': ['10% in Net Premium']},
#          '3 WHEELER (AUTO) AND ELECTRIC AUTO': {'Comm on Net Premium of 1st year': ['Package '
#                                                                                     '- '
#                                                                                     '20%',
#                                                                                     'TP '
#                                                                                     '- '
#                                                                                     '25%',
#                                                                                     'Package '
#                                                                                     '- '
#                                                                                     '20%',
#                                                                                     'TP '
#                                                                                     '- '
#                                                                                     '25%'],
#                                                 'Renewal': ['Package - 20%',
#                                                             'TP - 25%']},
#          'MAXICAB (6 to 20 Passengers)': {'Comm on Net Premium of 1st year': ['Package '
#                                                                               '- '
#                                                                               'Renewal '
#                                                                               '15% '
#                                                                               'in '
#                                                                               'OD '
#                                                                               'and '
#                                                                               '10% '
#                                                                               'in '
#                                                                               'TP',
#                                                                               'Package '
#                                                                               '- '
#                                                                               'Rollover  '
#                                                                               '10% '
#                                                                               'in '
#                                                                               'Net '
#                                                                               'Premium',
#                                                                               'TP '
#                                                                               '- '
#                                                                               '15%',
#                                                                               'Package '
#                                                                               '- '
#                                                                               'Renewal '
#                                                                               '15% '
#                                                                               'in '
#                                                                               'OD '
#                                                                               'and '
#                                                                               '10% '
#                                                                               'in '
#                                                                               'TP',
#                                                                               'Package '
#                                                                               '- '
#                                                                               'Rollover  '
#                                                                               '10% '
#                                                                               'in '
#                                                                               'Net '
#                                                                               'Premium',
#                                                                               'TP '
#                                                                               '- '
#                                                                               '15%'],
#                                           'Renewal': ['Package - Renewal 15% '
#                                                       'in OD and 10% in TP',
#                                                       'Package - Rollover  10% '
#                                                       'in Net Premium',
#                                                       'TP - 15%']},
#          'More than 30 Passengers': {'Comm on Net Premium of 1st year': ['4% '
#                                                                          'in '
#                                                                          'Net '
#                                                                          'Premium',
#                                                                          '4% '
#                                                                          'in '
#                                                                          'Net '
#                                                                          'Premium'],
#                                      'Renewal': ['4% in Net Premium']},
#          'School/Institutional staff buses': {'Comm on Net Premium of 1st year': ['35% '
#                                                                                   'in '
#                                                                                   'Net '
#                                                                                   'Premium',
#                                                                                   '35% '
#                                                                                   'in '
#                                                                                   'Net '
#                                                                                   'Premium'],
#                                               'Renewal': ['35% in Net '
#                                                           'Premium']},
#          'TAXI (1000 to 1500CC)': {'Comm on Net Premium of 1st year': ['10% in '
#                                                                        'Net '
#                                                                        'Premium',
#                                                                        '10% in '
#                                                                        'Net '
#                                                                        'Premium'],
#                                    'Renewal': ['10% in Net Premium']},
#          'TAXI ABOVE 1500CC  AND TAXI ELECTRIC': {'Comm on Net Premium of 1st year': ['15% '
#                                                                                       'in '
#                                                                                       'Net '
#                                                                                       'Premium',
#                                                                                       '15% '
#                                                                                       'in '
#                                                                                       'Net '
#                                                                                       'Premium'],
#                                                   'Renewal': ['15% in Net '
#                                                               'Premium']},
#          'TAXI UPTO 1000CC': {'Comm on Net Premium of 1st year': ['Package :OD '
#                                                                   '- 10% TP '
#                                                                   '-17.5%',
#                                                                   'TP - 15%',
#                                                                   'Package :OD '
#                                                                   '- 10% TP '
#                                                                   '-17.5%',
#                                                                   'TP - 15%'],
#                               'Renewal': ['Package :OD - 10% TP -17.5%',
#                                           'TP - 15%']}},
#  'Pvt Car': {'All other Cars except above model': {'Comm on Net Premium of 1st year': ['New '
#                                                                                        '- '
#                                                                                        '17.5%',
#                                                                                        'Package '
#                                                                                        '-15%',
#                                                                                        'SAOD '
#                                                                                        'renewal '
#                                                                                        '-12%, '
#                                                                                        'rollover '
#                                                                                        '- '
#                                                                                        '8%',
#                                                                                        'TP '
#                                                                                        '- '
#                                                                                        '15%',
#                                                                                        'New '
#                                                                                        '- '
#                                                                                        '17.5%',
#                                                                                        'Package '
#                                                                                        '-15%',
#                                                                                        'SAOD '
#                                                                                        'renewal '
#                                                                                        '-12%, '
#                                                                                        'rollover '
#                                                                                        '- '
#                                                                                        '8%',
#                                                                                        'TP '
#                                                                                        '- '
#                                                                                        '15%'],
#                                                    'Renewal': ['New - 17.5%',
#                                                                'Package -15%',
#                                                                'SAOD renewal '
#                                                                '-12%, rollover '
#                                                                '- 8%',
#                                                                'TP - 15%']},
#              'Diesel upto 1500cc (all model will cover)and all cars above 2500cc except (Tata Toyota Maruti Mahindra Honda Hyundai Kia)': {'Comm on Net Premium of 1st year': ['New '
#                                                                                                                                                                                '- '
#                                                                                                                                                                                '10%',
#                                                                                                                                                                                'Package '
#                                                                                                                                                                                '-5%',
#                                                                                                                                                                                'SAOD '
#                                                                                                                                                                                'renewal '
#                                                                                                                                                                                '-7%, '
#                                                                                                                                                                                'rollover '
#                                                                                                                                                                                '- '
#                                                                                                                                                                                '5%',
#                                                                                                                                                                                'TP '
#                                                                                                                                                                                '- '
#                                                                                                                                                                                '5%',
#                                                                                                                                                                                'HONDA',
#                                                                                                                                                                                'HYUNDAI',
#                                                                                                                                                                                'KIA',
#                                                                                                                                                                                'TP '
#                                                                                                                                                                                '- '
#                                                                                                                                                                                '5%'],
#                                                                                                                                            'Renewal': ['New '
#                                                                                                                                                        '- '
#                                                                                                                                                        '10%',
#                                                                                                                                                        'Package '
#                                                                                                                                                        '-5%',
#                                                                                                                                                        'SAOD '
#                                                                                                                                                        'renewal '
#                                                                                                                                                        '-7%, '
#                                                                                                                                                        'rollover '
#                                                                                                                                                        '- '
#                                                                                                                                                        '5%',
#                                                                                                                                                        'TP '
#                                                                                                                                                        '- '
#                                                                                                                                                        '5%']}},
#  'Two wheeler': {'above 350cc': {'Comm on Net Premium of 1st year': [0.15,
#                                                                      0.15,
#                                                                      'MARUTI',
#                                                                      'MAHINDRA'],
#                                  'Renewal': [0.15, 0.15]},
#                  'upto 350 cc AND ELECTRIC': {'Comm on Net Premium of 1st year': [0.2,
#                                                                                   0.2,
#                                                                                   'TATA',
#                                                                                   'TOYOTA'],
#                                               'Renewal': [0.2, 0.2]}}}

# %%
import json

with open("United.json", "w") as jsonFile:
    json.dump(tree, jsonFile, indent=4)
